# %%
#uncomment if you are running from google colab
# !pip install sklearn_crfsuite
# !pip install https://github.com/PyThaiNLP/pythainlp/archive/dev.zip
# !pip install fastai==1.0.46
# !pip install emoji
# !pip install gensim
# !pip install dill
# !pip install pandas
# !pip install sklearn
# !pip install numpy
# !pip install matplotlib
# !pip install pythainlp
# !pip install torch
# (in anaconda terminal)
# run "ipython kernel install --name "local-venv-kernel" --user"
# (in jupyter notebook)
# kernel --> change kernel

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from pythainlp.tokenize import word_tokenize
from gensim.models import KeyedVectors
import numpy as np

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import dill as pickle
import pandas as pd
from pythainlp import word_vector
from pythainlp.word_vector import sentence_vectorizer
import tensorflow as tf

import torch

# %%
def add_new_word(new_word,class_label,label_dict,vector_dict):
    vector = sentence_vectorizer(new_word, use_mean=True) 
    label_dict[TN] = class_label
    vector_dict[TN] = vector

# %%
df = pd.read_csv('407_dataset.csv')
label_dict = {}
vector_dict = {}

# %%
df_dict = df.to_dict()
for i in range(len(df_dict['Name'])):
    TN = df_dict["Name"][i].split()[0] 
    class_label = df_dict["Class"][i]
    if class_label == 'ของใช้ในชีวิตประจำวัน':
        class_label = 'ชอปปิ้ง'
    add_new_word(TN,class_label,label_dict,vector_dict)

# %%
for key in vector_dict:
    print(key)
# Out:
# ชาอินเดีย
# ขนมห้อง
# ข้าวเป็ดกระเทียม
# มาม่าผัด
# ข้าวหมูทอดมายองเนส
# ข้าวยำไก่แซ่บ
# เบเกอรี่
# โกโก้มุก
# โรตี
# ไวตามิลค์
# เลย์
# เส้นคลุก
# เค้กหน้านิ่ม
# หมี่เหลืองต้มยำหมูเด้ง
# กะเพราถาด
# หมูกระทียมกับเล้งแซ่บ
# ข้าวไก่ทงคัตสึกับเฟรนซ์ฟราย
# เจียวดาว
# น้ำฝรั่ง
# ชามะนาว
# ชิกฟิงเกอร์กับแซนด์วิชคาโบนาร่ากับโบโลน่า
# ไส้กรอกอีสาน
# หมูจุ่ม
# กล้วยทอด
# แฮปปี้โกโก้
# ข้าวซอยไก่พิเศษ
# ข้าวแกงกะหี่ไก่ทอด
# ขายทาโกะยากิ
# ขายเกี๊ยวซ่า
# ขายไมโลขนม
# ขายขนมจีบ
# ขายสเต็กอ้วนผอม
# ขายหมี่เหลืองซุปดูกต้มยำ
# ขายขนม
# ขายสุกี้แห้ง
# ไส้กรอก
# volcano
# ขายชิกฟิงเกอร์
# ขายแฮมชีส
# มิสเตอร์โดนัท
# พิซซ่า
# ขายมาม่า
# สเต็กไก่กับสลัดไก่กรอบ
# ขายเครปเย็น
# น้ำเปล่า
# ขาไก่
# ไข่นกกระทา
# ข้าวเต้าหู้ทรงเครื่อง
# ข้าวไก่ทอดราดซอสพะแนง
# กาโตะ
# ราชาหมูทอด
# แมคโดนัลด์
# มอคค่า
# ข้าวหมูกระเทียม
# ลาเต้
# นมชมพู
# ข้าวไก่ทอดทงคัตสึกับน้ำ
# เลย์มาม่านมถั่วเหลืองเยลลี่
# เฉาก๊วย
# ลูกชิ้นกับเกี๊ยวทอด
# ลูกอม
# หมี่เหลืองต้มยำ
# สลัดไก่กรอบ
# ช็อคโกแลตเบลเยี่ยม
# ข้าวยำไก่สไปซี่กับไก่สไปซี่ชิ้น
# ข้าวไก่ทอดมายองเนส
# ข้าวซอย
# โตและสด
# ลูกชิ้นสังคม
# หมี่เหลืองต้มยำปลา
# ขนมปังกับซีเรียลกับนม
# ข้าวหมูทอดมายองเนสกับพิซซ่า
# เบอร์เกอร์กับพายกับน้ำ
# ชาเขียวมุก
# ขนมเซเว่น
# หม่าล่า
# นมสดปั่นปีโป้
# เกี๊ยวทอด
# ข้าวแกงกะหรี่หมูทอด
# ข้าวหน้าหมูเกาหลี
# ราดหน้า
# โอริโอ้ปั่น
# เลย์นมถั่วเหลืองเอแคลร์
# ต๊อกบกกี
# แซนวิชคาโบนาร่าขนมกล้วยนมถั่วเหลือง
# ไก่รอว์ทรัค
# ป๊อปคอร์นกับโค้ก
# มาร์คซูชิ
# ชานมแคนตาลูป
# สปาเก็ตตี้คาโบนาร่า
# ขนมกับกาแฟ
# ข้าวขาหมูพิเศษกับข้าวซอยไก่พิเศษ
# เส้นเล็กต้มยำปลาเพิ่มไข่
# เสพติดชา
# ชายสี่หมี่เกี๊ยว
# น้ำปั่น
# ก๋วยตี๋ยวเรืออองตอง
# เดลี่ควีน
# โยเกิร์ตปั่นกับมาม่า
# หมี่คลุก
# ข้าวมันไก่ทอด
# โก๋แก่
# mongni
# ข้าวไก่เทอริยากิกับซูชิ
# ขนมปังกับน้ำ
# เคเอฟซี
# เบียร์
# ปาท่องโก๋
# น้ำส้มคั้น
# กุ้งอบวุ้นเส้น
# ข้าวเหนียวมะม่วง
# นม
# ยาคูล
# ชาพีช
# pepsi
# กาแฟ
# สลัด
# น้ำดื่ม
# ยำวุ้นเส้น
# ส้มตำ
# ไก่ย่าง
# ไก่ทอด
# ต้มเลือดหมู
# ข้าวเปล่า
# ชาไทย
# ชาเย็น
# ชานมไข่มุก
# ขนมจีน
# บะหมี่สามเหลือง
# บิงซู
# น้ำแข็งใส
# ปังเย็น
# เฟรนช์ฟรายด์
# มันนึ่ง
# ข้าวโพด
# ฟักทอง
# ลูกชิ้น
# ขนมปังปิ้ง
# ไอติม
# ไอศครีม
# Gummy
# ผัก
# ผลไม้
# แอปเปิ้ล
# แก้วมังกร
# สับปะรด
# ฝรั่ง
# เกม
# Fidget
# หูฟัง
# Netflix
# ดูหนัง
# ดูดวง
# Internet
# เติมเกม
# ค่าโทรศัพท์
# ค่ารถแดง
# ค่ารถเมล์
# ค่าเครื่องบิน
# ค่าวินมอไซด์
# ค่าเรือ
# น้ำมันรถ
# ค่าผ่านทางด่วน
# ค่าที่จอดรถ
# ค่าแท็กซี่
# bts
# mrt
# arl
# รถไฟฟ้า
# จักรยาน
# สกูตเตอร์
# ค่ารถตู้
# Benzac
# ยาแต้มสิว
# พาราเซตามอล
# ขูดหินปูน
# จัดฟัน
# หาหมอ
# แผ่นแปะสิว
# น้ำเกลือ
# นวด
# โบท็อค
# ร้อยไหม
# แวกซ์ขน
# ไปโรงพยาบาล
# Counterpain
# ยาฆ่าเชื้อ
# ค่าหอ
# ค่าโรงแรม
# ค่าเช่าบ้าน
# ผ่อนคอนโด
# ค่าห้อง
# ค่าน้ำ
# ค่าไฟ
# ที่ตักขยะ
# ตระกล้า
# ตู้เย็น
# ตู้เสื้อผ้า
# ไมโครเวฟ
# หมอน
# พรมเช็ดเท้า
# พรม
# หมอนข้าง
# ผ้าม่าน
# ห้องน้ำแมว
# ทรายแมว
# กรง
# ของเล่น
# หญ้า
# ปลอกคอ
# สบู่
# กระเป๋ากับถุงเท้า
# ดินสอ
# ช้อนส้อม
# น้ำมันโรสฮิป
# ครีมกันแดด
# mi
# กางเกงขาสั้น
# เสื้อยืด
# รองเท้าส้นสูง
# ถุงน่อง
# กระเป๋าผ้า
# แชมพู
# กล่องใส่หูฟัง
# บัตรคันจิ
# กางเกงใน
# เคสมือถือ
# เมาส์ไร้สาย
# ครีม
# น้ำตบฮาดะลาโบะ
# กระดาษทิชชู
# ยาสีฟัน
# ชุดชั้นใน
# ผ้าอนามัย
# เจลล้างมือ
# แลคตาซิด
# ปากกาไวท์บอร์ด
# แป้ง
# โลชั่น
# แปรงสีฟัน
# น้ำยาบ้วนปาก
# โทนเนอร์
# มาส์กหน้า
# cleanser
# เซรั่ม
# โฟมล้างหน้า
# ครีมนวดผม
# น้ำมันมะพร้าว
# go
# เซรั่มบำรุงผม
# cotton
# ไหมขัดฟัน
# สำลี
# แป้งเย็นตรางู
# โลออน
# แพมเพิส
# ผ้าอ้อม
# วาสลีน
# โฟมล้างมือ
# มีดโกนหนวด
# ลิปสติก
# มาสคาร่า
# ลิป
# ดินสอเขียนคิ้ว
# อายแชโดว์
# พาเลท
# รองพื้น
# บรัชออน
# คอนซีลเลอร์
# แป้งพัฟ
# BB
# primer
# contour
# ไฮไลท์
# หน้ากากอนามัย
# หน้ากากผ้า
# คัตเตอร์
# ปากกา
# ดินสอ2B
# ยางลบ
# แปรงลบกระดาน
# สก๊อตเทปใส
# กาวสองหน้า
# กาวลาเทค
# สายชาร์จ
# adapter
# สเปร์น้ำแร่
# carefree
# ถุงเท้า
# รองเท้าแตะ
# รองเท้าผ้าใบ
# รองเท้าวิ่ง
# เสื้อเชิ้ต
# เสื้อนักศึกษา
# กระโปรงพีท
# กระโปรงนักเรียน
# ทรงเอ
# สมุด
# หนังสือภาษาญี่ปุ่น
# หนังสือการ์ตูน
# แผ่นรองเมาส์
# กระเป๋าสตางค์
# หมวกกันน็อค
# หมวก
# jacket
# กิ๊บ
# ยางมัดผม
# พวงกุญแจ
# ตุ๊กตา
# กรรไกร
# ตะไบ
# แหนบ
# ที่กันคิ้ว
# เข็ม
# ด้าย
# บอร์ด
# หมุด
# คลิปหนีบกระดาษ
# กระดาษA4
# กระดาษรายงาน
# สมุดกราฟ
# ลิกขวิด
# เบบี้ออยล์
# น้ำหอม
# ใยขัดต้ว
# สครับผิว
# กางเกงยีนส์
# แปรงแต่งหน้า
# ที่่แคะหู
# กรรไกรตัดเล็บ
# ไดร์เป่าผม
# ที่หนีบผม
# เครื่องฟอกอากาศ
# แจ่มฟ้า
# กล่องรองเท้า
# กล่องเก็บผ้า
# นาฬิกา
# พัดลมไอเย็น
# แปรงล้างหลอด
# แก้วสแตนเลส
# โคมไฟ
# โคมไฟตั้งโต๊ะ
# โคมไฟตกแต่ง
# โคมไฟ3D
# กล่องเก็บของ
# น้ำยาปรับผ้านุ่ม
# ผงซักฟอก
# น้ำยาซักผ้า
# ไบกอน
# ซอฟเฟล
# น้ำยาล้างห้องน้ำ
# แปรงขัดส้วม
# ผ้าเช็ดทำความสะอาด
# น้ำยาเช็ดกระจก
# กะละมัง
# ลูกกลิ้ง
# ถังน้ำ
# ปลอกหมอน
# ผ้าห่ม
# ผ้าเช็ดตัว
# ผ้าปูที่นอน
# ชุดเครื่องนอน
# ที่นอนยางพารา
# ลำโพง
# ทีวี
# โน๊ตบุ๊ค
# ถุงดำ
# ชาม
# แก้วน้ำ
# หม้อ
# หม้อไฟฟ้า
# กระทะไฟฟ้า
# หม้ออเนกประสงค์
# หม้อหุงข้าว
# กาต้มน้ำ
# เครื่องชงกาแฟ
# ตะหลิว
# ตะเกียบ
# ช้อน
# ส้อม
# จาน
# ถ้วย
# ชั้นวางของ
# โต๊ะคอม
# ชั้นวางหนังสือ
# เตารีด
# แก๊ส
# เก้าอี้
# โซฟา
# ชุดโต๊ะกินข้าว
# เต้นท์
# ผ้าเช็ดหน้า
# หลอดไฟ
# สายยาง
# ก็อกน้ำ
# ฝักบัว
# เครื่องทำน้ำอุ่น
# กระบองเพชร
# พัดลม
# ต้นไม้
# ไม้กวาด

# %%
TN = 'ข้าวมันไก่'
try:
    a = vector_dict[TN]
    dist_from_1 = {}
    x = torch.from_numpy(a)
    for key in vector_dict:
        y = torch.from_numpy(vector_dict[key])
        dist = F.cosine_similarity(x,y)
        dist_from_1[key] = dist
except:
    print(TN,'not exists')
    a = sentence_vectorizer(TN, use_mean=True) 
    dist_from_1 = {}
    x = torch.from_numpy(a)
    for key in vector_dict:
        y = torch.from_numpy(vector_dict[key])
        dist = F.cosine_similarity(x,y)
        dist_from_1[key] = dist
# Out:
# ข้าวมันไก่ not exists

# %%
sorted_dict = sorted((value,key) for (key,value) in dist_from_1.items())
for key in sorted_dict:
    print(key)
    print(label_dict[key[1]])
# Out:
# (tensor([0.], dtype=torch.float64), 'BB')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'Benzac')
# สุขภาพ
# (tensor([0.], dtype=torch.float64), 'Counterpain')
# สุขภาพ
# (tensor([0.], dtype=torch.float64), 'Fidget')
# บันเทิง
# (tensor([0.], dtype=torch.float64), 'Gummy')
# อาหาร
# (tensor([0.], dtype=torch.float64), 'Internet')
# บันเทิง
# (tensor([0.], dtype=torch.float64), 'Netflix')
# บันเทิง
# (tensor([0.], dtype=torch.float64), 'arl')
# การเดินทาง
# (tensor([0.], dtype=torch.float64), 'carefree')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'cleanser')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'contour')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'jacket')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'mongni')
# อาหาร
# (tensor([0.], dtype=torch.float64), 'กะละมัง')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'กาต้มน้ำ')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'ครีมกันแดด')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'ครีมนวดผม')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'คลิปหนีบกระดาษ')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'ค่าเรือ')
# การเดินทาง
# (tensor([0.], dtype=torch.float64), 'ค่าโทรศัพท์')
# บันเทิง
# (tensor([0.], dtype=torch.float64), 'ชั้นวางของ')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'ชั้นวางหนังสือ')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'ช้อนส้อม')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'ตะหลิว')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'น้ำมันรถ')
# การเดินทาง
# (tensor([0.], dtype=torch.float64), 'น้ำยาบ้วนปาก')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'น้ำส้มคั้น')
# อาหาร
# (tensor([0.], dtype=torch.float64), 'ปลอกหมอน')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'ผ้าปูที่นอน')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'พรมเช็ดเท้า')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'มาสคาร่า')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'วาสลีน')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'หมอนข้าง')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'อายแชโดว์')
# ชอปปิ้ง
# (tensor([0.], dtype=torch.float64), 'เครื่องทำน้ำอุ่น')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'เครื่องฟอกอากาศ')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'แวกซ์ขน')
# สุขภาพ
# (tensor([0.], dtype=torch.float64), 'โคมไฟตั้งโต๊ะ')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'โน๊ตบุ๊ค')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'ไบกอน')
# ของใช้ในครัวเรือน
# (tensor([0.], dtype=torch.float64), 'ไหมขัดฟัน')
# ชอปปิ้ง
# (tensor([0.0014], dtype=torch.float64), 'นม')
# อาหาร
# (tensor([0.0106], dtype=torch.float64), 'go')
# ชอปปิ้ง
# (tensor([0.0107], dtype=torch.float64), 'กระดาษA4')
# ชอปปิ้ง
# (tensor([0.0115], dtype=torch.float64), 'เบียร์')
# อาหาร
# (tensor([0.0127], dtype=torch.float64), 'ค่ารถแดง')
# การเดินทาง
# (tensor([0.0155], dtype=torch.float64), 'ค่าวินมอไซด์')
# การเดินทาง
# (tensor([0.0158], dtype=torch.float64), 'ลิป')
# ชอปปิ้ง
# (tensor([0.0172], dtype=torch.float64), 'หม้อไฟฟ้า')
# ของใช้ในครัวเรือน
# (tensor([0.0182], dtype=torch.float64), 'ดูหนัง')
# บันเทิง
# (tensor([0.0208], dtype=torch.float64), 'ลาเต้')
# อาหาร
# (tensor([0.0209], dtype=torch.float64), 'ซอฟเฟล')
# ของใช้ในครัวเรือน
# (tensor([0.0217], dtype=torch.float64), 'บิงซู')
# อาหาร
# (tensor([0.0221], dtype=torch.float64), 'โลออน')
# ชอปปิ้ง
# (tensor([0.0226], dtype=torch.float64), 'แก้วมังกร')
# อาหาร
# (tensor([0.0245], dtype=torch.float64), 'กาโตะ')
# อาหาร
# (tensor([0.0256], dtype=torch.float64), 'ไฮไลท์')
# ชอปปิ้ง
# (tensor([0.0267], dtype=torch.float64), 'แลคตาซิด')
# ชอปปิ้ง
# (tensor([0.0268], dtype=torch.float64), 'บัตรคันจิ')
# ชอปปิ้ง
# (tensor([0.0295], dtype=torch.float64), 'น้ำมันโรสฮิป')
# ชอปปิ้ง
# (tensor([0.0305], dtype=torch.float64), 'ค่าไฟ')
# ที่อยู่อาศัย
# (tensor([0.0307], dtype=torch.float64), 'มอคค่า')
# อาหาร
# (tensor([0.0322], dtype=torch.float64), 'นาฬิกา')
# ของใช้ในครัวเรือน
# (tensor([0.0325], dtype=torch.float64), 'โบท็อค')
# สุขภาพ
# (tensor([0.0335], dtype=torch.float64), 'หม้อ')
# ของใช้ในครัวเรือน
# (tensor([0.0335], dtype=torch.float64), 'เกม')
# บันเทิง
# (tensor([0.0335], dtype=torch.float64), 'จาน')
# ของใช้ในครัวเรือน
# (tensor([0.0345], dtype=torch.float64), 'โอริโอ้ปั่น')
# อาหาร
# (tensor([0.0351], dtype=torch.float64), 'แป้ง')
# ชอปปิ้ง
# (tensor([0.0356], dtype=torch.float64), 'โทนเนอร์')
# ชอปปิ้ง
# (tensor([0.0357], dtype=torch.float64), 'ทีวี')
# ของใช้ในครัวเรือน
# (tensor([0.0367], dtype=torch.float64), 'บรัชออน')
# ชอปปิ้ง
# (tensor([0.0368], dtype=torch.float64), 'นมชมพู')
# อาหาร
# (tensor([0.0378], dtype=torch.float64), 'ดินสอ2B')
# ชอปปิ้ง
# (tensor([0.0386], dtype=torch.float64), 'ยางมัดผม')
# ชอปปิ้ง
# (tensor([0.0388], dtype=torch.float64), 'ผลไม้')
# อาหาร
# (tensor([0.0400], dtype=torch.float64), 'สปาเก็ตตี้คาโบนาร่า')
# อาหาร
# (tensor([0.0429], dtype=torch.float64), 'ขายทาโกะยากิ')
# อาหาร
# (tensor([0.0441], dtype=torch.float64), 'ค่าน้ำ')
# ที่อยู่อาศัย
# (tensor([0.0451], dtype=torch.float64), 'น้ำตบฮาดะลาโบะ')
# ชอปปิ้ง
# (tensor([0.0453], dtype=torch.float64), 'ชาไทย')
# อาหาร
# (tensor([0.0467], dtype=torch.float64), 'คอนซีลเลอร์')
# ชอปปิ้ง
# (tensor([0.0473], dtype=torch.float64), 'ค่าเครื่องบิน')
# การเดินทาง
# (tensor([0.0476], dtype=torch.float64), 'หญ้า')
# ของใช้ในครัวเรือน
# (tensor([0.0479], dtype=torch.float64), 'หนังสือภาษาญี่ปุ่น')
# ชอปปิ้ง
# (tensor([0.0486], dtype=torch.float64), 'ไก่รอว์ทรัค')
# อาหาร
# (tensor([0.0488], dtype=torch.float64), 'เลย์')
# อาหาร
# (tensor([0.0491], dtype=torch.float64), 'แพมเพิส')
# ชอปปิ้ง
# (tensor([0.0498], dtype=torch.float64), 'รถไฟฟ้า')
# การเดินทาง
# (tensor([0.0504], dtype=torch.float64), 'เข็ม')
# ชอปปิ้ง
# (tensor([0.0512], dtype=torch.float64), 'ข้าวซอย')
# อาหาร
# (tensor([0.0513], dtype=torch.float64), 'ชาอินเดีย')
# อาหาร
# (tensor([0.0513], dtype=torch.float64), 'ทรายแมว')
# ของใช้ในครัวเรือน
# (tensor([0.0514], dtype=torch.float64), 'ค่าโรงแรม')
# ที่อยู่อาศัย
# (tensor([0.0515], dtype=torch.float64), 'น้ำแข็งใส')
# อาหาร
# (tensor([0.0516], dtype=torch.float64), 'กาแฟ')
# อาหาร
# (tensor([0.0517], dtype=torch.float64), 'มาร์คซูชิ')
# อาหาร
# (tensor([0.0521], dtype=torch.float64), 'ขายชิกฟิงเกอร์')
# อาหาร
# (tensor([0.0528], dtype=torch.float64), 'ตุ๊กตา')
# ชอปปิ้ง
# (tensor([0.0533], dtype=torch.float64), 'โต๊ะคอม')
# ของใช้ในครัวเรือน
# (tensor([0.0551], dtype=torch.float64), 'เลย์นมถั่วเหลืองเอแคลร์')
# อาหาร
# (tensor([0.0556], dtype=torch.float64), 'ครีม')
# ชอปปิ้ง
# (tensor([0.0560], dtype=torch.float64), 'โตและสด')
# อาหาร
# (tensor([0.0563], dtype=torch.float64), 'ค่าหอ')
# ที่อยู่อาศัย
# (tensor([0.0564], dtype=torch.float64), 'แซนวิชคาโบนาร่าขนมกล้วยนมถั่วเหลือง')
# อาหาร
# (tensor([0.0566], dtype=torch.float64), 'จักรยาน')
# การเดินทาง
# (tensor([0.0572], dtype=torch.float64), 'ขายสุกี้แห้ง')
# อาหาร
# (tensor([0.0572], dtype=torch.float64), 'หนังสือการ์ตูน')
# ชอปปิ้ง
# (tensor([0.0578], dtype=torch.float64), 'ผัก')
# อาหาร
# (tensor([0.0581], dtype=torch.float64), 'ชามะนาว')
# อาหาร
# (tensor([0.0582], dtype=torch.float64), 'ทรงเอ')
# ชอปปิ้ง
# (tensor([0.0584], dtype=torch.float64), 'หาหมอ')
# สุขภาพ
# (tensor([0.0593], dtype=torch.float64), 'ชานมไข่มุก')
# อาหาร
# (tensor([0.0594], dtype=torch.float64), 'ค่าห้อง')
# ที่อยู่อาศัย
# (tensor([0.0594], dtype=torch.float64), 'น้ำฝรั่ง')
# อาหาร
# (tensor([0.0597], dtype=torch.float64), 'แจ่มฟ้า')
# ของใช้ในครัวเรือน
# (tensor([0.0603], dtype=torch.float64), 'มันนึ่ง')
# อาหาร
# (tensor([0.0608], dtype=torch.float64), 'มาส์กหน้า')
# ชอปปิ้ง
# (tensor([0.0609], dtype=torch.float64), 'เฟรนช์ฟรายด์')
# อาหาร
# (tensor([0.0611], dtype=torch.float64), 'ข้าวไก่เทอริยากิกับซูชิ')
# อาหาร
# (tensor([0.0624], dtype=torch.float64), 'หมวกกันน็อค')
# ชอปปิ้ง
# (tensor([0.0626], dtype=torch.float64), 'บอร์ด')
# ชอปปิ้ง
# (tensor([0.0626], dtype=torch.float64), 'ชุดโต๊ะกินข้าว')
# ของใช้ในครัวเรือน
# (tensor([0.0630], dtype=torch.float64), 'จัดฟัน')
# สุขภาพ
# (tensor([0.0638], dtype=torch.float64), 'ข้าวหน้าหมูเกาหลี')
# อาหาร
# (tensor([0.0641], dtype=torch.float64), 'โคมไฟ3D')
# ของใช้ในครัวเรือน
# (tensor([0.0642], dtype=torch.float64), 'ราชาหมูทอด')
# อาหาร
# (tensor([0.0649], dtype=torch.float64), 'ต้นไม้')
# ของใช้ในครัวเรือน
# (tensor([0.0653], dtype=torch.float64), 'ก็อกน้ำ')
# ของใช้ในครัวเรือน
# (tensor([0.0661], dtype=torch.float64), 'รองเท้าวิ่ง')
# ชอปปิ้ง
# (tensor([0.0662], dtype=torch.float64), 'ขนมห้อง')
# อาหาร
# (tensor([0.0662], dtype=torch.float64), 'ปังเย็น')
# อาหาร
# (tensor([0.0663], dtype=torch.float64), 'น้ำปั่น')
# อาหาร
# (tensor([0.0663], dtype=torch.float64), 'ถ้วย')
# ของใช้ในครัวเรือน
# (tensor([0.0669], dtype=torch.float64), 'หม่าล่า')
# อาหาร
# (tensor([0.0671], dtype=torch.float64), 'ขายขนม')
# อาหาร
# (tensor([0.0676], dtype=torch.float64), 'แก๊ส')
# ของใช้ในครัวเรือน
# (tensor([0.0683], dtype=torch.float64), 'ขนมปังกับซีเรียลกับนม')
# อาหาร
# (tensor([0.0683], dtype=torch.float64), 'พาเลท')
# ชอปปิ้ง
# (tensor([0.0685], dtype=torch.float64), 'ฝรั่ง')
# อาหาร
# (tensor([0.0691], dtype=torch.float64), 'แป้งเย็นตรางู')
# ชอปปิ้ง
# (tensor([0.0701], dtype=torch.float64), 'สครับผิว')
# ชอปปิ้ง
# (tensor([0.0701], dtype=torch.float64), 'เติมเกม')
# บันเทิง
# (tensor([0.0706], dtype=torch.float64), 'ชาพีช')
# อาหาร
# (tensor([0.0706], dtype=torch.float64), 'ต้มเลือดหมู')
# อาหาร
# (tensor([0.0717], dtype=torch.float64), 'ข้าวซอยไก่พิเศษ')
# อาหาร
# (tensor([0.0717], dtype=torch.float64), 'กาวลาเทค')
# ชอปปิ้ง
# (tensor([0.0721], dtype=torch.float64), 'หน้ากากผ้า')
# ชอปปิ้ง
# (tensor([0.0743], dtype=torch.float64), 'ถุงดำ')
# ของใช้ในครัวเรือน
# (tensor([0.0743], dtype=torch.float64), 'ชุดเครื่องนอน')
# ของใช้ในครัวเรือน
# (tensor([0.0744], dtype=torch.float64), 'ขนมกับกาแฟ')
# อาหาร
# (tensor([0.0750], dtype=torch.float64), 'ข้าวไก่ทงคัตสึกับเฟรนซ์ฟราย')
# อาหาร
# (tensor([0.0762], dtype=torch.float64), 'ไปโรงพยาบาล')
# สุขภาพ
# (tensor([0.0763], dtype=torch.float64), 'สายชาร์จ')
# ชอปปิ้ง
# (tensor([0.0765], dtype=torch.float64), 'พรม')
# ของใช้ในครัวเรือน
# (tensor([0.0765], dtype=torch.float64), 'น้ำมันมะพร้าว')
# ชอปปิ้ง
# (tensor([0.0766], dtype=torch.float64), 'กระทะไฟฟ้า')
# ของใช้ในครัวเรือน
# (tensor([0.0782], dtype=torch.float64), 'ขนมปังกับน้ำ')
# อาหาร
# (tensor([0.0790], dtype=torch.float64), 'ค่าผ่านทางด่วน')
# การเดินทาง
# (tensor([0.0790], dtype=torch.float64), 'ข้าวหมูกระเทียม')
# อาหาร
# (tensor([0.0792], dtype=torch.float64), 'กระเป๋าผ้า')
# ชอปปิ้ง
# (tensor([0.0798], dtype=torch.float64), 'ร้อยไหม')
# สุขภาพ
# (tensor([0.0803], dtype=torch.float64), 'ขายแฮมชีส')
# อาหาร
# (tensor([0.0811], dtype=torch.float64), 'สลัดไก่กรอบ')
# อาหาร
# (tensor([0.0814], dtype=torch.float64), 'ที่กันคิ้ว')
# ชอปปิ้ง
# (tensor([0.0816], dtype=torch.float64), 'เก้าอี้')
# ของใช้ในครัวเรือน
# (tensor([0.0828], dtype=torch.float64), 'กาวสองหน้า')
# ชอปปิ้ง
# (tensor([0.0832], dtype=torch.float64), 'กล้วยทอด')
# อาหาร
# (tensor([0.0837], dtype=torch.float64), 'กล่องรองเท้า')
# ของใช้ในครัวเรือน
# (tensor([0.0839], dtype=torch.float64), 'ไวตามิลค์')
# อาหาร
# (tensor([0.0858], dtype=torch.float64), 'ข้าวโพด')
# อาหาร
# (tensor([0.0870], dtype=torch.float64), 'เค้กหน้านิ่ม')
# อาหาร
# (tensor([0.0870], dtype=torch.float64), 'หมวก')
# ชอปปิ้ง
# (tensor([0.0879], dtype=torch.float64), 'ลำโพง')
# ของใช้ในครัวเรือน
# (tensor([0.0894], dtype=torch.float64), 'ข้าวยำไก่สไปซี่กับไก่สไปซี่ชิ้น')
# อาหาร
# (tensor([0.0927], dtype=torch.float64), 'ปากกา')
# ชอปปิ้ง
# (tensor([0.0944], dtype=torch.float64), 'ขายมาม่า')
# อาหาร
# (tensor([0.0948], dtype=torch.float64), 'เจียวดาว')
# อาหาร
# (tensor([0.0953], dtype=torch.float64), 'ห้องน้ำแมว')
# ของใช้ในครัวเรือน
# (tensor([0.0957], dtype=torch.float64), 'หม้ออเนกประสงค์')
# ของใช้ในครัวเรือน
# (tensor([0.0965], dtype=torch.float64), 'เสื้อนักศึกษา')
# ชอปปิ้ง
# (tensor([0.0971], dtype=torch.float64), 'สมุดกราฟ')
# ชอปปิ้ง
# (tensor([0.0989], dtype=torch.float64), 'แปรงลบกระดาน')
# ชอปปิ้ง
# (tensor([0.0992], dtype=torch.float64), 'มาม่าผัด')
# อาหาร
# (tensor([0.1008], dtype=torch.float64), 'ข้าวเป็ดกระเทียม')
# อาหาร
# (tensor([0.1025], dtype=torch.float64), 'ชิกฟิงเกอร์กับแซนด์วิชคาโบนาร่ากับโบโลน่า')
# อาหาร
# (tensor([0.1031], dtype=torch.float64), 'หมูจุ่ม')
# อาหาร
# (tensor([0.1038], dtype=torch.float64), 'ก๋วยตี๋ยวเรืออองตอง')
# อาหาร
# (tensor([0.1040], dtype=torch.float64), 'กรง')
# ของใช้ในครัวเรือน
# (tensor([0.1049], dtype=torch.float64), 'สมุด')
# ชอปปิ้ง
# (tensor([0.1074], dtype=torch.float64), 'กระดาษรายงาน')
# ชอปปิ้ง
# (tensor([0.1105], dtype=torch.float64), 'ข้าวเปล่า')
# อาหาร
# (tensor([0.1121], dtype=torch.float64), 'กระโปรงนักเรียน')
# ชอปปิ้ง
# (tensor([0.1136], dtype=torch.float64), 'ปากกาไวท์บอร์ด')
# ชอปปิ้ง
# (tensor([0.1140], dtype=torch.float64), 'ข้าวขาหมูพิเศษกับข้าวซอยไก่พิเศษ')
# อาหาร
# (tensor([0.1154], dtype=torch.float64), 'ที่ตักขยะ')
# ของใช้ในครัวเรือน
# (tensor([0.1161], dtype=torch.float64), 'ค่าที่จอดรถ')
# การเดินทาง
# (tensor([0.1162], dtype=torch.float64), 'ที่หนีบผม')
# ชอปปิ้ง
# (tensor([0.1196], dtype=torch.float64), 'ขนมเซเว่น')
# อาหาร
# (tensor([0.1214], dtype=torch.float64), 'ค่ารถเมล์')
# การเดินทาง
# (tensor([0.1228], dtype=torch.float64), 'กล่องเก็บผ้า')
# ของใช้ในครัวเรือน
# (tensor([0.1237], dtype=torch.float64), 'ของเล่น')
# ของใช้ในครัวเรือน
# (tensor([0.1262], dtype=torch.float64), 'แปรงล้างหลอด')
# ของใช้ในครัวเรือน
# (tensor([0.1313], dtype=torch.float64), 'ดินสอเขียนคิ้ว')
# ชอปปิ้ง
# (tensor([0.1324], dtype=torch.float64), 'เคสมือถือ')
# ชอปปิ้ง
# (tensor([0.1391], dtype=torch.float64), 'ที่่แคะหู')
# ชอปปิ้ง
# (tensor([0.1407], dtype=torch.float64), 'น้ำดื่ม')
# อาหาร
# (tensor([0.1421], dtype=torch.float64), 'น้ำยาปรับผ้านุ่ม')
# ของใช้ในครัวเรือน
# (tensor([0.1441], dtype=torch.float64), 'ตระกล้า')
# ของใช้ในครัวเรือน
# (tensor([0.1473], dtype=torch.float64), 'เบอร์เกอร์กับพายกับน้ำ')
# อาหาร
# (tensor([0.1488], dtype=torch.float64), 'สลัด')
# อาหาร
# (tensor([0.1490], dtype=torch.float64), 'หน้ากากอนามัย')
# ชอปปิ้ง
# (tensor([0.1503], dtype=torch.float64), 'แผ่นรองเมาส์')
# ชอปปิ้ง
# (tensor([0.1543], dtype=torch.float64), 'ค่าแท็กซี่')
# การเดินทาง
# (tensor([0.1568], dtype=torch.float64), 'ขนมปังปิ้ง')
# อาหาร
# (tensor([0.1575], dtype=torch.float64), 'เส้นคลุก')
# อาหาร
# (tensor([0.1582], dtype=torch.float64), 'บะหมี่สามเหลือง')
# อาหาร
# (tensor([0.1594], dtype=torch.float64), 'ค่ารถตู้')
# การเดินทาง
# (tensor([0.1759], dtype=torch.float64), 'กรรไกรตัดเล็บ')
# ชอปปิ้ง
# (tensor([0.1775], dtype=torch.float64), 'นวด')
# สุขภาพ
# (tensor([0.1783], dtype=torch.float64), 'mi')
# ชอปปิ้ง
# (tensor([0.1788], dtype=torch.float64), 'น้ำยาล้างห้องน้ำ')
# ของใช้ในครัวเรือน
# (tensor([0.1820], dtype=torch.float64), 'กระเป๋ากับถุงเท้า')
# ชอปปิ้ง
# (tensor([0.1845], dtype=torch.float64), 'ลิกขวิด')
# ชอปปิ้ง
# (tensor([0.1853], dtype=torch.float64), 'ต๊อกบกกี')
# อาหาร
# (tensor([0.1861], dtype=torch.float64), 'พัดลมไอเย็น')
# ของใช้ในครัวเรือน
# (tensor([0.1879], dtype=torch.float64), 'ข้าวเหนียวมะม่วง')
# อาหาร
# (tensor([0.1885], dtype=torch.float64), 'สเปร์น้ำแร่')
# ชอปปิ้ง
# (tensor([0.1907], dtype=torch.float64), 'เส้นเล็กต้มยำปลาเพิ่มไข่')
# อาหาร
# (tensor([0.1921], dtype=torch.float64), 'ไดร์เป่าผม')
# ชอปปิ้ง
# (tensor([0.1922], dtype=torch.float64), 'ป๊อปคอร์นกับโค้ก')
# อาหาร
# (tensor([0.1936], dtype=torch.float64), 'น้ำหอม')
# ชอปปิ้ง
# (tensor([0.1942], dtype=torch.float64), 'ยาแต้มสิว')
# สุขภาพ
# (tensor([0.2037], dtype=torch.float64), 'โคมไฟตกแต่ง')
# ของใช้ในครัวเรือน
# (tensor([0.2039], dtype=torch.float64), 'เซรั่มบำรุงผม')
# ชอปปิ้ง
# (tensor([0.2044], dtype=torch.float64), 'เลย์มาม่านมถั่วเหลืองเยลลี่')
# อาหาร
# (tensor([0.2050], dtype=torch.float64), 'โยเกิร์ตปั่นกับมาม่า')
# อาหาร
# (tensor([0.2059], dtype=torch.float64), 'ข้าวไก่ทอดทงคัตสึกับน้ำ')
# อาหาร
# (tensor([0.2114], dtype=torch.float64), 'โก๋แก่')
# อาหาร
# (tensor([0.2114], dtype=torch.float64), 'กล่องเก็บของ')
# ของใช้ในครัวเรือน
# (tensor([0.2169], dtype=torch.float64), 'สเต็กไก่กับสลัดไก่กรอบ')
# อาหาร
# (tensor([0.2219], dtype=torch.float64), 'หมูกระทียมกับเล้งแซ่บ')
# อาหาร
# (tensor([0.2231], dtype=torch.float64), 'ขายหมี่เหลืองซุปดูกต้มยำ')
# อาหาร
# (tensor([0.2278], dtype=torch.float64), 'ขูดหินปูน')
# สุขภาพ
# (tensor([0.2318], dtype=torch.float64), 'กล่องใส่หูฟัง')
# ชอปปิ้ง
# (tensor([0.2333], dtype=torch.float64), 'ไข่นกกระทา')
# อาหาร
# (tensor([0.2339], dtype=torch.float64), 'เสพติดชา')
# อาหาร
# (tensor([0.2350], dtype=torch.float64), 'ด้าย')
# ชอปปิ้ง
# (tensor([0.2374], dtype=torch.float64), 'ที่นอนยางพารา')
# ของใช้ในครัวเรือน
# (tensor([0.2426], dtype=torch.float64), 'ชานมแคนตาลูป')
# อาหาร
# (tensor([0.2438], dtype=torch.float64), 'กุ้งอบวุ้นเส้น')
# อาหาร
# (tensor([0.2476], dtype=torch.float64), 'ยาคูล')
# อาหาร
# (tensor([0.2614], dtype=torch.float64), 'ผ้าเช็ดทำความสะอาด')
# ของใช้ในครัวเรือน
# (tensor([0.2639], dtype=torch.float64), 'เซรั่ม')
# ชอปปิ้ง
# (tensor([0.2690], dtype=torch.float64), 'ชายสี่หมี่เกี๊ยว')
# อาหาร
# (tensor([0.2728], dtype=torch.float64), 'ขายเกี๊ยวซ่า')
# อาหาร
# (tensor([0.2759], dtype=torch.float64), 'แปรงแต่งหน้า')
# ชอปปิ้ง
# (tensor([0.2822], dtype=torch.float64), 'สบู่')
# ชอปปิ้ง
# (tensor([0.2835], dtype=torch.float64), 'ข้าวหมูทอดมายองเนส')
# อาหาร
# (tensor([0.2884], dtype=torch.float64), 'ชาม')
# ของใช้ในครัวเรือน
# (tensor([0.2980], dtype=torch.float64), 'นมสดปั่นปีโป้')
# อาหาร
# (tensor([0.3038], dtype=torch.float64), 'ขายไมโลขนม')
# อาหาร
# (tensor([0.3039], dtype=torch.float64), 'ขายเครปเย็น')
# อาหาร
# (tensor([0.3084], dtype=torch.float64), 'กระโปรงพีท')
# ชอปปิ้ง
# (tensor([0.3085], dtype=torch.float64), 'ค่าเช่าบ้าน')
# ที่อยู่อาศัย
# (tensor([0.3091], dtype=torch.float64), 'หมี่เหลืองต้มยำปลา')
# อาหาร
# (tensor([0.3106], dtype=torch.float64), 'ข้าวยำไก่แซ่บ')
# อาหาร
# (tensor([0.3171], dtype=torch.float64), 'ขายสเต็กอ้วนผอม')
# อาหาร
# (tensor([0.3190], dtype=torch.float64), 'แก้วสแตนเลส')
# ของใช้ในครัวเรือน
# (tensor([0.3206], dtype=torch.float64), 'แผ่นแปะสิว')
# สุขภาพ
# (tensor([0.3222], dtype=torch.float64), 'น้ำยาเช็ดกระจก')
# ของใช้ในครัวเรือน
# (tensor([0.3230], dtype=torch.float64), 'ข้าวเต้าหู้ทรงเครื่อง')
# อาหาร
# (tensor([0.3248], dtype=torch.float64), 'สก๊อตเทปใส')
# ชอปปิ้ง
# (tensor([0.3301], dtype=torch.float64), 'หลอดไฟ')
# ของใช้ในครัวเรือน
# (tensor([0.3332], dtype=torch.float64), 'ลูกชิ้นสังคม')
# อาหาร
# (tensor([0.3351], dtype=torch.float64), 'หมอน')
# ของใช้ในครัวเรือน
# (tensor([0.3411], dtype=torch.float64), 'เครื่องชงกาแฟ')
# ของใช้ในครัวเรือน
# (tensor([0.3448], dtype=torch.float64), 'ไส้กรอกอีสาน')
# อาหาร
# (tensor([0.3480], dtype=torch.float64), 'ข้าวหมูทอดมายองเนสกับพิซซ่า')
# อาหาร
# (tensor([0.3503], dtype=torch.float64), 'กางเกงยีนส์')
# ชอปปิ้ง
# (tensor([0.3683], dtype=torch.float64), 'ขายขนมจีบ')
# อาหาร
# (tensor([0.3800], dtype=torch.float64), 'ดินสอ')
# ชอปปิ้ง
# (tensor([0.3831], dtype=torch.float64), 'เดลี่ควีน')
# อาหาร
# (tensor([0.3999], dtype=torch.float64), 'ลูกชิ้นกับเกี๊ยวทอด')
# อาหาร
# (tensor([0.4116], dtype=torch.float64), 'ใยขัดต้ว')
# ชอปปิ้ง
# (tensor([0.4128], dtype=torch.float64), 'เจลล้างมือ')
# ชอปปิ้ง
# (tensor([0.4285], dtype=torch.float64), 'เบเกอรี่')
# อาหาร
# (tensor([0.4365], dtype=torch.float64), 'แอปเปิ้ล')
# อาหาร
# (tensor([0.4413], dtype=torch.float64), 'เกี๊ยวทอด')
# อาหาร
# (tensor([0.4578], dtype=torch.float64), 'เมาส์ไร้สาย')
# ชอปปิ้ง
# (tensor([0.4598], dtype=torch.float64), 'หมี่คลุก')
# อาหาร
# (tensor([0.4647], dtype=torch.float64), 'หมุด')
# ชอปปิ้ง
# (tensor([0.4686], dtype=torch.float64), 'แป้งพัฟ')
# ชอปปิ้ง
# (tensor([0.4715], dtype=torch.float64), 'ไมโครเวฟ')
# ของใช้ในครัวเรือน
# (tensor([0.4729], dtype=torch.float64), 'ช้อน')
# ของใช้ในครัวเรือน
# (tensor([0.4768], dtype=torch.float64), 'ข้าวแกงกะหี่ไก่ทอด')
# อาหาร
# (tensor([0.4834], dtype=torch.float64), 'โคมไฟ')
# ของใช้ในครัวเรือน
# (tensor([0.4862], dtype=torch.float64), 'แปรงขัดส้วม')
# ของใช้ในครัวเรือน
# (tensor([0.4864], dtype=torch.float64), 'หมี่เหลืองต้มยำ')
# อาหาร
# (tensor([0.4884], dtype=torch.float64), 'หม้อหุงข้าว')
# ของใช้ในครัวเรือน
# (tensor([0.4919], dtype=torch.float64), 'หมี่เหลืองต้มยำหมูเด้ง')
# อาหาร
# (tensor([0.4988], dtype=torch.float64), 'มิสเตอร์โดนัท')
# อาหาร
# (tensor([0.5143], dtype=torch.float64), 'กระดาษทิชชู')
# ชอปปิ้ง
# (tensor([0.5153], dtype=torch.float64), 'กรรไกร')
# ชอปปิ้ง
# (tensor([0.5235], dtype=torch.float64), 'สับปะรด')
# อาหาร
# (tensor([0.5248], dtype=torch.float64), 'โกโก้มุก')
# อาหาร
# (tensor([0.5327], dtype=torch.float64), 'ข้าวไก่ทอดราดซอสพะแนง')
# อาหาร
# (tensor([0.5337], dtype=torch.float64), 'มีดโกนหนวด')
# ชอปปิ้ง
# (tensor([0.5659], dtype=torch.float64), 'ข้าวแกงกะหรี่หมูทอด')
# อาหาร
# (tensor([0.6144], dtype=torch.float64), 'ผ่อนคอนโด')
# ที่อยู่อาศัย
# (tensor([0.6153], dtype=torch.float64), 'เสื้อยืด')
# ชอปปิ้ง
# (tensor([0.6158], dtype=torch.float64), 'ตู้เย็น')
# ของใช้ในครัวเรือน
# (tensor([0.6224], dtype=torch.float64), 'ผ้าห่ม')
# ของใช้ในครัวเรือน
# (tensor([0.6323], dtype=torch.float64), 'สำลี')
# ชอปปิ้ง
# (tensor([0.6363], dtype=torch.float64), 'แมคโดนัลด์')
# อาหาร
# (tensor([0.6393], dtype=torch.float64), 'ข้าวไก่ทอดมายองเนส')
# อาหาร
# (tensor([0.6416], dtype=torch.float64), 'ชาเขียวมุก')
# อาหาร
# (tensor([0.6439], dtype=torch.float64), 'ถุงเท้า')
# ชอปปิ้ง
# (tensor([0.6472], dtype=torch.float64), 'แฮปปี้โกโก้')
# อาหาร
# (tensor([0.6483], dtype=torch.float64), 'ช็อคโกแลตเบลเยี่ยม')
# อาหาร
# (tensor([0.7074], dtype=torch.float64), 'หูฟัง')
# บันเทิง
# (tensor([0.7156], dtype=torch.float64), 'น้ำเกลือ')
# สุขภาพ
# (tensor([0.7277], dtype=torch.float64), 'ส้มตำ')
# อาหาร
# (tensor([0.7290], dtype=torch.float64), 'ขนมจีน')
# อาหาร
# (tensor([0.7293], dtype=torch.float64), 'ฟักทอง')
# อาหาร
# (tensor([0.7638], dtype=torch.float64), 'พัดลม')
# ของใช้ในครัวเรือน
# (tensor([0.7849], dtype=torch.float64), 'กิ๊บ')
# ชอปปิ้ง
# (tensor([0.7853], dtype=torch.float64), 'ไม้กวาด')
# ของใช้ในครัวเรือน
# (tensor([0.7900], dtype=torch.float64), 'โฟมล้างมือ')
# ชอปปิ้ง
# (tensor([0.7912], dtype=torch.float64), 'ชุดชั้นใน')
# ชอปปิ้ง
# (tensor([0.7944], dtype=torch.float64), 'ลูกอม')
# อาหาร
# (tensor([0.7948], dtype=torch.float64), 'โรตี')
# อาหาร
# (tensor([0.8139], dtype=torch.float64), 'ผงซักฟอก')
# ของใช้ในครัวเรือน
# (tensor([0.8216], dtype=torch.float64), 'เบบี้ออยล์')
# ชอปปิ้ง
# (tensor([0.8267], dtype=torch.float64), 'ตะเกียบ')
# ของใช้ในครัวเรือน
# (tensor([0.8283], dtype=torch.float64), 'ยำวุ้นเส้น')
# อาหาร
# (tensor([0.8386], dtype=torch.float64), 'ไส้กรอก')
# อาหาร
# (tensor([0.8579], dtype=torch.float64), 'แชมพู')
# ชอปปิ้ง
# (tensor([0.8609], dtype=torch.float64), 'กะเพราถาด')
# อาหาร
# (tensor([0.8671], dtype=torch.float64), 'น้ำยาซักผ้า')
# ของใช้ในครัวเรือน
# (tensor([0.9186], dtype=torch.float64), 'โฟมล้างหน้า')
# ชอปปิ้ง
# (tensor([0.9343], dtype=torch.float64), 'ยาสีฟัน')
# ชอปปิ้ง
# (tensor([0.9563], dtype=torch.float64), 'พิซซ่า')
# อาหาร
# (tensor([0.9568], dtype=torch.float64), 'ไก่ย่าง')
# อาหาร
# (tensor([0.9618], dtype=torch.float64), 'ส้อม')
# ของใช้ในครัวเรือน
# (tensor([0.9674], dtype=torch.float64), 'กางเกงขาสั้น')
# ชอปปิ้ง
# (tensor([0.9714], dtype=torch.float64), 'ลูกชิ้น')
# อาหาร
# (tensor([0.9764], dtype=torch.float64), 'กางเกงใน')
# ชอปปิ้ง
# (tensor([0.9782], dtype=torch.float64), 'ผ้าเช็ดหน้า')
# ของใช้ในครัวเรือน
# (tensor([0.9782], dtype=torch.float64), 'โซฟา')
# ของใช้ในครัวเรือน
# (tensor([0.9799], dtype=torch.float64), 'ถังน้ำ')
# ของใช้ในครัวเรือน
# (tensor([0.9805], dtype=torch.float64), 'เสื้อเชิ้ต')
# ชอปปิ้ง
# (tensor([0.9814], dtype=torch.float64), 'ข้าวมันไก่ทอด')
# อาหาร
# (tensor([0.9814], dtype=torch.float64), 'ไก่ทอด')
# อาหาร
# (tensor([0.9832], dtype=torch.float64), 'bts')
# การเดินทาง
# (tensor([0.9878], dtype=torch.float64), 'ลิปสติก')
# ชอปปิ้ง
# (tensor([0.9891], dtype=torch.float64), 'เคเอฟซี')
# อาหาร
# (tensor([0.9907], dtype=torch.float64), 'ตู้เสื้อผ้า')
# ของใช้ในครัวเรือน
# (tensor([0.9908], dtype=torch.float64), 'ผ้าม่าน')
# ของใช้ในครัวเรือน
# (tensor([0.9931], dtype=torch.float64), 'แก้วน้ำ')
# ของใช้ในครัวเรือน
# (tensor([0.9933], dtype=torch.float64), 'กระบองเพชร')
# ของใช้ในครัวเรือน
# (tensor([0.9942], dtype=torch.float64), 'แหนบ')
# ชอปปิ้ง
# (tensor([0.9948], dtype=torch.float64), 'cotton')
# ชอปปิ้ง
# (tensor([0.9956], dtype=torch.float64), 'ปลอกคอ')
# ของใช้ในครัวเรือน
# (tensor([0.9966], dtype=torch.float64), 'ลูกกลิ้ง')
# ของใช้ในครัวเรือน
# (tensor([0.9969], dtype=torch.float64), 'พาราเซตามอล')
# สุขภาพ
# (tensor([0.9971], dtype=torch.float64), 'รองเท้าแตะ')
# ชอปปิ้ง
# (tensor([0.9979], dtype=torch.float64), 'primer')
# ชอปปิ้ง
# (tensor([0.9979], dtype=torch.float64), 'พวงกุญแจ')
# ชอปปิ้ง
# (tensor([0.9985], dtype=torch.float64), 'เต้นท์')
# ของใช้ในครัวเรือน
# (tensor([0.9986], dtype=torch.float64), 'รองเท้าส้นสูง')
# ชอปปิ้ง
# (tensor([0.9987], dtype=torch.float64), 'โลชั่น')
# ชอปปิ้ง
# (tensor([0.9987], dtype=torch.float64), 'ไอศครีม')
# อาหาร
# (tensor([0.9988], dtype=torch.float64), 'ฝักบัว')
# ของใช้ในครัวเรือน
# (tensor([0.9994], dtype=torch.float64), 'คัตเตอร์')
# ชอปปิ้ง
# (tensor([0.9994], dtype=torch.float64), 'volcano')
# อาหาร
# (tensor([0.9994], dtype=torch.float64), 'รองพื้น')
# ชอปปิ้ง
# (tensor([0.9995], dtype=torch.float64), 'ปาท่องโก๋')
# อาหาร
# (tensor([0.9995], dtype=torch.float64), 'ยาฆ่าเชื้อ')
# สุขภาพ
# (tensor([0.9995], dtype=torch.float64), 'สายยาง')
# ของใช้ในครัวเรือน
# (tensor([0.9996], dtype=torch.float64), 'ดูดวง')
# บันเทิง
# (tensor([0.9996], dtype=torch.float64), 'ขาไก่')
# อาหาร
# (tensor([0.9996], dtype=torch.float64), 'เตารีด')
# ของใช้ในครัวเรือน
# (tensor([0.9996], dtype=torch.float64), 'ผ้าอ้อม')
# ชอปปิ้ง
# (tensor([0.9996], dtype=torch.float64), 'เฉาก๊วย')
# อาหาร
# (tensor([0.9996], dtype=torch.float64), 'ราดหน้า')
# อาหาร
# (tensor([0.9996], dtype=torch.float64), 'ยางลบ')
# ชอปปิ้ง
# (tensor([0.9997], dtype=torch.float64), 'ตะไบ')
# ชอปปิ้ง
# (tensor([0.9997], dtype=torch.float64), 'mrt')
# การเดินทาง
# (tensor([0.9997], dtype=torch.float64), 'ถุงน่อง')
# ชอปปิ้ง
# (tensor([0.9997], dtype=torch.float64), 'ผ้าเช็ดตัว')
# ของใช้ในครัวเรือน
# (tensor([0.9998], dtype=torch.float64), 'กระเป๋าสตางค์')
# ชอปปิ้ง
# (tensor([0.9998], dtype=torch.float64), 'น้ำเปล่า')
# อาหาร
# (tensor([0.9998], dtype=torch.float64), 'pepsi')
# อาหาร
# (tensor([0.9998], dtype=torch.float64), 'ไอติม')
# อาหาร
# (tensor([0.9998], dtype=torch.float64), 'แปรงสีฟัน')
# ชอปปิ้ง
# (tensor([0.9998], dtype=torch.float64), 'adapter')
# ชอปปิ้ง
# (tensor([0.9998], dtype=torch.float64), 'สกูตเตอร์')
# การเดินทาง
# (tensor([0.9998], dtype=torch.float64), 'รองเท้าผ้าใบ')
# ชอปปิ้ง
# (tensor([0.9999], dtype=torch.float64), 'ชาเย็น')
# อาหาร
# (tensor([0.9999], dtype=torch.float64), 'ผ้าอนามัย')
# ชอปปิ้ง

# %%
label_dict['ข้าว'] = food
